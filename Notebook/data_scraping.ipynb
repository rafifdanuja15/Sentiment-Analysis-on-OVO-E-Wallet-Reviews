# %% [markdown]
# Script ini melakukan scraping ulasan pengguna untuk aplikasi OVO dari Google Play Store.
# Data yang diambil mencakup ulasan terbaru dalam bahasa Indonesia.
#
# Output:
#     - ulasan_raw_ovo.csv: File CSV dengan kolom reviewId dan content

# %% [markdown]
# # Import Library & Dependencies

# %%
# !pip install google-play-scraper pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 2.7 MB/s eta 0:00:00
# ...

# %%
from google_play_scraper import Sort, reviews
import pandas as pd
import time

# %% [markdown]
# # Data Scraping

# %%
# Konfigurasi Target
app_id = 'ovo.id'

# %%
print(f"Memulai proses scraping ulasan untuk: {app_id}")

# Melakukan scraping 20.000 ulasan terbaru
# Kita gunakan count=20000. Google Play Scraper akan berusaha mengambil sebanyak itu.
result, _ = reviews(
    app_id,
    lang='id',        # Bahasa Indonesia
    country='id',     # Lokasi Indonesia
    sort=Sort.NEWEST, # Terbaru
    count=20000       # Target jumlah ulasan
)

# Memasukkan hasil ke dalam DataFrame
df_ovo = pd.DataFrame(result)

# Menampilkan informasi dataset
print(f"Jumlah data yang berhasil diambil: {len(df_ovo)}")
# Out:
# Memulai proses scraping ulasan untuk: ovo.id
# Jumlah data yang berhasil diambil: 20000

# %%
df_ovo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              20000 non-null  object
#  1   userName              20000 non-null  object
#  2   userImage             20000 non-null  object
#  3   content               20000 non-null  object
#  4   score                 20000 non-null  int64
#  5   thumbsUpCount         20000 non-null  int64
#  6   reviewCreatedVersion  14740 non-null  object
#  7   at                    20000 non-null  datetime64[ns]
#  8   replyContent          369 non-null    object
#  9   repliedAt             369 non-null    datetime64[ns]
#  10  appVersion            14740 non-null  object
# dtypes: datetime64[ns](2), int64(2), object(7)
# memory usage: 1.7+ MB

# %% [markdown]
# # Menyimpan Data Frame

# %%
# Memilih hanya kolom reviewId dan content
df_ovo_clean = df_ovo[['reviewId', 'content']]

# Menyimpan ke CSV mentah (hanya kolom terpilih)
df_ovo_clean.to_csv("ulasan_raw_ovo.csv", index=False)
print("File 'ulasan_raw_ovo.csv' berhasil disimpan dengan kolom reviewId dan content.")

# Menampilkan 5 data teratas untuk memastikan kolom sudah sesuai
df_ovo_clean.head()
# Out:
# File 'ulasan_raw_ovo.csv' berhasil disimpan dengan kolom reviewId dan content.
#                                reviewId  \
# 0  8b86e94a-43e1-4b55-9e9b-6ae2ebc547e8
# 1  90012396-f936-4be3-9911-011ea29fa685
# 2  a2e17aa1-6355-483f-b332-aeb5fe1e570c
# 3  20ef7f4c-87db-4369-8113-97f3001c3c9b
# 4  81e94f85-e705-4d20-9638-70907cb4f7d0
#
#                                              content
# 0  upgrade kamera gak kebuka gimana ini padahal p...
# 1                                  aplikasi mantappp
# 2                                                 ok
# 3                                               cuus
# 4  aplikasi sampah jangan pakai ovo gaes ribet ti...
